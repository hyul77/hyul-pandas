# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.2-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.11.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.2)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.2

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
import numpy as np
import pandas as pd
import category_encoders as ce
from tqdm.auto import tqdm
from collections import defaultdict
from sklearn.decomposition import TruncatedSVD, NMF, SparsePCA
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn import svm
from sklearn import datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import RandomizedSearchCV
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import warnings
import easydict
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
def recall5(answer_df, submission_df): #

    primary_col = answer_df.columns[0]
    secondary_col = answer_df.columns[1]

    # submission의 예측이 각각 5개인지 확인
    prediction_counts = submission_df.groupby(primary_col).size()
    if not all(prediction_counts == 5):
        raise ValueError(f"Each {primary_col} should have exactly 5 {secondary_col} predictions.")


    # submission의 예측된 값들에 null값이 있는지 확인
    if submission_df[secondary_col].isnull().any():
        raise ValueError(f"Predicted {secondary_col} contains NULL values.")

    # 예측값에 중복이 있는지 확인
    duplicated_preds = submission_df.groupby(primary_col).apply(lambda x: x[secondary_col].duplicated().any())
    if duplicated_preds.any():
        raise ValueError(f"Predicted {secondary_col} contains duplicates for some {primary_col}.")


    # Filter the submission dataframe based on the primary_col present in the answer dataframe
    # primary_col 즉 resume_seq가 양측에 있는지 확인 후 남김
    submission_df = submission_df[submission_df[primary_col].isin(answer_df[primary_col])]

    # For each primary_col, get the top 5 predicted secondary_col values
    #
    top_5_preds = submission_df.groupby(primary_col).apply(lambda x: x[secondary_col].head(5).tolist()).to_dict()

    # Convert the answer_df to a dictionary for easier lookup
    true_dict = answer_df.groupby(primary_col).apply(lambda x: x[secondary_col].tolist()).to_dict()


    individual_recalls = []
    for key, val in true_dict.items():
        if key in top_5_preds:
            correct_matches = len(set(true_dict[key]) & set(top_5_preds[key]))
            individual_recall = correct_matches / min(len(val), 5) # 공정한 평가를 가능하게 위하여 분모(k)를 'min(len(val), 5)' 로 설정함
            individual_recalls.append(individual_recall)


    recall = np.mean(individual_recalls)
    return recall

# %% [markdown]
# # data 불러오기

# %%
apply_train = pd.read_csv('./apply_train.csv')
apply_train = apply_train.sort_values(by='resume_seq')
apply_train
# Out:
#       resume_seq recruitment_seq
# 11989     U00001          R05210
# 342       U00001          R05288
# 51174     U00001          R04536
# 28858     U00001          R06065
# 50591     U00002          R01103
# ...          ...             ...
# 13950     U08481          R00225
# 22895     U08481          R05500
# 33843     U08482          R03633
# 54343     U08482          R03743
# 38314     U08482          R06282
#
# [57946 rows x 2 columns]

# %%
apply_train2 = pd.read_csv('./apply_train.csv')
apply_train2 = apply_train2.sort_values(by='recruitment_seq')
apply_train2
# Out:
#       resume_seq recruitment_seq
# 19619     U06543          R00001
# 40253     U04491          R00001
# 4511      U04364          R00001
# 13507     U08247          R00001
# 45925     U03957          R00001
# ...          ...             ...
# 45561     U00749          R06695
# 906       U01486          R06695
# 25460     U07172          R06695
# 41774     U04863          R06695
# 54060     U03473          R06695
#
# [57946 rows x 2 columns]

# %%
count_per_resume = apply_train.groupby('resume_seq')['recruitment_seq'].count()
# 최솟값(min)
min_value = count_per_resume.min()

# 최댓값(max)
max_value = count_per_resume.max()

print("최솟값:", min_value)
print("최댓값:", max_value)
# Out:
# 최솟값: 2
# 최댓값: 77

# %%
count_per_resume2 = apply_train.groupby('resume_seq')['recruitment_seq']
count_per_resume2

# %%
count_per_recruitment = apply_train2.groupby('recruitment_seq')['resume_seq'].count()
# 최솟값(min)
min_value = count_per_recruitment.min()

# 최댓값(max)
max_value = count_per_recruitment.max()

print("최솟값:", min_value)
print("최댓값:", max_value)
# Out:
# 최솟값: 1
# 최댓값: 78

# %% [markdown]
# 사람 -> 회사 최소 2 최대 77
# 회사 -> 사람 최소 1 최대 78
# 사람 -> 회사 추천 하는게 바람직 (train, test 나누기 힘듦)

# %% [markdown]
# # Data 불러오고 합치기

# %% [markdown]
# ## resume (resume_seq 기준)

# %%
resume_train = apply_train.groupby('resume_seq')['recruitment_seq'].apply(';'.join).reset_index()
resume_train
# Out:
#      resume_seq                                    recruitment_seq
# 0        U00001                        R05210;R05288;R04536;R06065
# 1        U00002  R01103;R01730;R06019;R01960;R02946;R02346;R045...
# 2        U00003                               R03301;R04918;R01460
# 3        U00004  R05367;R04166;R02355;R02003;R02899;R00312;R000...
# 4        U00005                               R00832;R03914;R00374
# ...         ...                                                ...
# 8477     U08478                                      R02170;R03939
# 8478     U08479          R02988;R03837;R01470;R04036;R04196;R02787
# 8479     U08480                                      R03152;R00803
# 8480     U08481                               R06253;R00225;R05500
# 8481     U08482                               R03633;R03743;R06282
#
# [8482 rows x 2 columns]

# %%
resume = pd.read_csv('./resume.csv')
resume = resume.sort_values(by='resume_seq')
resume
# Out:
#      resume_seq    reg_date updated_date  degree  graduate_date  hope_salary  \
# 1690     U00001  2019-12-27   2020-02-01       4           2009       1500.0
# 3979     U00002  2020-04-24   2020-04-29       4           2005          0.0
# 5648     U00003  2018-02-14   2020-07-08       4           2004          0.0
# 1367     U00004  2017-10-26   2020-04-27       4           2011          0.0
# 5242     U00005  2020-03-18   2020-04-08       4           2011          0.0
# ...         ...         ...          ...     ...            ...          ...
# 3811     U08478  2020-02-05   2020-03-31       4           2003          0.0
# 2227     U08479  2016-02-17   2020-07-15       3              0       2500.0
# 2657     U08480  2019-11-13   2020-06-24       4              0          0.0
# 6619     U08481  2020-07-09   2020-11-23       4           2015          0.0
# 567      U08482  2020-11-29   2020-11-29       4              0          0.0
#
#       last_salary                    text_keyword job_code_seq1 job_code_seq2  \
# 1690       1500.0                            디자이너   재료·화학·섬유·의복           NaN
# 3979          0.0                            디자이너   재료·화학·섬유·의복           NaN
# 5648          0.0                   남성복디자이너;TD캐주얼   재료·화학·섬유·의복           NaN
# 1367          0.0                       상품기획;영업기획   재료·화학·섬유·의복           NaN
# 5242          0.0                인사;총무;경영;MD;상품기획   재료·화학·섬유·의복           NaN
# ...           ...                             ...           ...           ...
# 3811       2700.0                            상품기획   재료·화학·섬유·의복           NaN
# 2227       2300.0                            디자이너   재료·화학·섬유·의복           NaN
# 2657          0.0  VMD;텍스타일디자인;섬유디자인;니트디자인;여성복디자인           디자인           NaN
# 6619       2700.0                 상품기획;머천다이저;기획MD   재료·화학·섬유·의복           NaN
# 567           0.0     상품기획;영업MD;머천다이저;기획MD;마케팅;PR   재료·화학·섬유·의복           NaN
#
#      job_code_seq3  career_month career_job_code
# 1690           NaN             0             NaN
# 3979           NaN            73     기타 공공;개인서비스
# 5648           NaN           113     섬유;봉제;가방;의류
# 1367           NaN            27     섬유;봉제;가방;의류
# 5242           NaN             0             NaN
# ...            ...           ...             ...
# 3811           NaN            60     섬유;봉제;가방;의류
# 2227           NaN            59      디자인;CAD;설계
# 2657           NaN             0             NaN
# 6619           NaN             8     섬유;봉제;가방;의류
# 567            NaN             0             NaN
#
# [8482 rows x 13 columns]

# %%
resume_certificate = pd.read_csv('./resume_certificate.csv')
resume_certificate = resume_certificate.sort_values(by='resume_seq')
resume_certificate
# Out:
#      resume_seq certificate_contents
# 6855     U00002     자동차 운전면허 (2종 보통)
# 6458     U00003             운전면허2종보통
# 4424     U00003             컬러리스트 기사
# 7553     U00003            워드프로세서 1급
# 1509     U00004              정보처리기능사
# ...         ...                  ...
# 6980     U08480              컬러리스트기사
# 7043     U08480        컴퓨터패션디자인운용마스터
# 335      U08481           컴퓨터활용능력 2급
# 7386     U08482         컴퓨터그래픽스운용기능사
# 4544     U08482        패션 머천다이징산업 기사
#
# [12975 rows x 2 columns]

# %%
resume_certificate = resume_certificate.dropna(subset=['certificate_contents'])
resume_certificate = resume_certificate.groupby('resume_seq')['certificate_contents'].apply(';'.join).reset_index()
resume_certificate
# Out:
#      resume_seq                               certificate_contents
# 0        U00002                                   자동차 운전면허 (2종 보통)
# 1        U00003                        운전면허2종보통;컬러리스트 기사;워드프로세서 1급
# 2        U00004             정보처리기능사;유통관리사 2급;MOS EXCEL 2003 EXPERT
# 3        U00006                        운전면허 1종 보통;문서실무사1급;유통관리사 2급
# 4        U00007  샵마스터;자동차운전면허1종 보통;패턴 양장 기능사;MICROSOFT OFFICE E...
# ...         ...                                                ...
# 5971     U08476                                           운전면허2종보통
# 5972     U08479                                       컴퓨터그래픽스운용기능사
# 5973     U08480     2종 보통 운전면허증;컴퓨터그래픽스운용기능사;컬러리스트기사;컴퓨터패션디자인운용마스터
# 5974     U08481                                         컴퓨터활용능력 2급
# 5975     U08482                         컴퓨터그래픽스운용기능사;패션 머천다이징산업 기사
#
# [5976 rows x 2 columns]

# %%
resume_education = pd.read_csv('./resume_education.csv')
resume_education = resume_education.sort_values(by='resume_seq')
resume_education
# Out:
#      resume_seq  hischool_type_seq hischool_special_type hischool_nation  \
# 5714     U00001                 21                   일반고              공립
# 3375     U00002                  0                    기타              기타
# 201      U00003                 21                   일반고              공립
# 586      U00004                 21                   일반고              공립
# 7970     U00005                 21                   일반고              공립
# ...         ...                ...                   ...             ...
# 6923     U08478                 21                   일반고              공립
# 5091     U08479                 21                   자율고              사립
# 2775     U08480                  0                    기타              기타
# 334      U08481                 21                   자율고              공립
# 2988     U08482                 16                  특성화고              사립
#
#      hischool_gender  hischool_location_seq  univ_type_seq1  univ_type_seq2  \
# 5714            여자학교                      4               5               5
# 3375              기타                      0               5               5
# 201             남여공학                      6               5               5
# 586             남여공학                      5               5               5
# 7970            여자학교                      5               0               0
# ...              ...                    ...             ...             ...
# 6923            남여공학                      3               5               5
# 5091            남여공학                      3               3               6
# 2775              기타                      0               5               5
# 334             여자학교                      5               5               5
# 2988            여자학교                      8               0               0
#
#       univ_transfer  univ_location       univ_major univ_sub_major  \
# 5714              0             17              NaN            NaN
# 3375              0              3              NaN            NaN
# 201               0             17              NaN            NaN
# 586               0              5              NaN            NaN
# 7970              0              0              NaN            NaN
# ...             ...            ...              ...            ...
# 6923              0              5              NaN            NaN
# 5091              0              3              가정과            NaN
# 2775              0             10  미술대학섬유패션코디네이션학과            NaN
# 334               0              5              NaN            NaN
# 2988              0              0              NaN            NaN
#
#       univ_major_type  univ_score
# 5714                9        20.0
# 3375                8        90.0
# 201                 4        90.0
# 586                 3        70.0
# 7970               10        50.0
# ...               ...         ...
# 6923               19         0.0
# 5091                9         0.0
# 2775                9        80.0
# 334                 9        60.0
# 2988                9        80.0
#
# [8482 rows x 14 columns]

# %%
resume_language = pd.read_csv('./resume_language.csv')
resume_language = resume_language.sort_values(by='resume_seq')
resume_language
# Out:
#     resume_seq  language  exam_name   score
# 45      U00004         2         11  661.62
# 701     U00005         2          4  873.74
# 205     U00039         2          4  848.48
# 645     U00054         2          4  909.09
# 769     U00067         2          2   20.00
# ..         ...       ...        ...     ...
# 424     U08443         4          5  676.77
# 728     U08461         2          4  676.77
# 278     U08465         2         11   11.11
# 212     U08472         2          4  611.11
# 707     U08482         2         11  600.00
#
# [869 rows x 4 columns]

# %%
resume_language['lang_exam_score'] = resume_language['language'].astype(str) + ';' + resume_language['exam_name'].astype(str) + ';' + resume_language['score'].astype(str)
resume_language = resume_language.drop(['language','exam_name', 'score', 'score'], axis=1)
resume_language
# Out:
#     resume_seq lang_exam_score
# 45      U00004     2;11;661.62
# 701     U00005      2;4;873.74
# 205     U00039      2;4;848.48
# 645     U00054      2;4;909.09
# 769     U00067        2;2;20.0
# ..         ...             ...
# 424     U08443      4;5;676.77
# 728     U08461      2;4;676.77
# 278     U08465      2;11;11.11
# 212     U08472      2;4;611.11
# 707     U08482      2;11;600.0
#
# [869 rows x 2 columns]

# %%
resume_language = resume_language.dropna(subset=['lang_exam_score'])
resume_language = resume_language.groupby('resume_seq')['lang_exam_score'].apply('&'.join).reset_index()
resume_language
# Out:
#     resume_seq lang_exam_score
# 0       U00004     2;11;661.62
# 1       U00005      2;4;873.74
# 2       U00039      2;4;848.48
# 3       U00054      2;4;909.09
# 4       U00067        2;2;20.0
# ..         ...             ...
# 815     U08443      4;5;676.77
# 816     U08461      2;4;676.77
# 817     U08465      2;11;11.11
# 818     U08472      2;4;611.11
# 819     U08482      2;11;600.0
#
# [820 rows x 2 columns]

# %%
merged_resume = pd.merge(resume, resume_certificate, on='resume_seq', how='left')
merged_resume
# Out:
#      resume_seq    reg_date updated_date  degree  graduate_date  hope_salary  \
# 0        U00001  2019-12-27   2020-02-01       4           2009       1500.0
# 1        U00002  2020-04-24   2020-04-29       4           2005          0.0
# 2        U00003  2018-02-14   2020-07-08       4           2004          0.0
# 3        U00004  2017-10-26   2020-04-27       4           2011          0.0
# 4        U00005  2020-03-18   2020-04-08       4           2011          0.0
# ...         ...         ...          ...     ...            ...          ...
# 8477     U08478  2020-02-05   2020-03-31       4           2003          0.0
# 8478     U08479  2016-02-17   2020-07-15       3              0       2500.0
# 8479     U08480  2019-11-13   2020-06-24       4              0          0.0
# 8480     U08481  2020-07-09   2020-11-23       4           2015          0.0
# 8481     U08482  2020-11-29   2020-11-29       4              0          0.0
#
#       last_salary                    text_keyword job_code_seq1 job_code_seq2  \
# 0          1500.0                            디자이너   재료·화학·섬유·의복           NaN
# 1             0.0                            디자이너   재료·화학·섬유·의복           NaN
# 2             0.0                   남성복디자이너;TD캐주얼   재료·화학·섬유·의복           NaN
# 3             0.0                       상품기획;영업기획   재료·화학·섬유·의복           NaN
# 4             0.0                인사;총무;경영;MD;상품기획   재료·화학·섬유·의복           NaN
# ...           ...                             ...           ...           ...
# 8477       2700.0                            상품기획   재료·화학·섬유·의복           NaN
# 8478       2300.0                            디자이너   재료·화학·섬유·의복           NaN
# 8479          0.0  VMD;텍스타일디자인;섬유디자인;니트디자인;여성복디자인           디자인           NaN
# 8480       2700.0                 상품기획;머천다이저;기획MD   재료·화학·섬유·의복           NaN
# 8481          0.0     상품기획;영업MD;머천다이저;기획MD;마케팅;PR   재료·화학·섬유·의복           NaN
#
#      job_code_seq3  career_month career_job_code  \
# 0              NaN             0             NaN
# 1              NaN            73     기타 공공;개인서비스
# 2              NaN           113     섬유;봉제;가방;의류
# 3              NaN            27     섬유;봉제;가방;의류
# 4              NaN             0             NaN
# ...            ...           ...             ...
# 8477           NaN            60     섬유;봉제;가방;의류
# 8478           NaN            59      디자인;CAD;설계
# 8479           NaN             0             NaN
# 8480           NaN             8     섬유;봉제;가방;의류
# 8481           NaN             0             NaN
#
#                                 certificate_contents
# 0                                                NaN
# 1                                   자동차 운전면허 (2종 보통)
# 2                        운전면허2종보통;컬러리스트 기사;워드프로세서 1급
# 3             정보처리기능사;유통관리사 2급;MOS EXCEL 2003 EXPERT
# 4                                                NaN
# ...                                              ...
# 8477                                             NaN
# 8478                                    컴퓨터그래픽스운용기능사
# 8479  2종 보통 운전면허증;컴퓨터그래픽스운용기능사;컬러리스트기사;컴퓨터패션디자인운용마스터
# 8480                                      컴퓨터활용능력 2급
# 8481                      컴퓨터그래픽스운용기능사;패션 머천다이징산업 기사
#
# [8482 rows x 14 columns]

# %%
merged_resume = pd.merge(merged_resume, resume_education, on='resume_seq', how='left')
merged_resume
# Out:
#      resume_seq    reg_date updated_date  degree  graduate_date  hope_salary  \
# 0        U00001  2019-12-27   2020-02-01       4           2009       1500.0
# 1        U00002  2020-04-24   2020-04-29       4           2005          0.0
# 2        U00003  2018-02-14   2020-07-08       4           2004          0.0
# 3        U00004  2017-10-26   2020-04-27       4           2011          0.0
# 4        U00005  2020-03-18   2020-04-08       4           2011          0.0
# ...         ...         ...          ...     ...            ...          ...
# 8477     U08478  2020-02-05   2020-03-31       4           2003          0.0
# 8478     U08479  2016-02-17   2020-07-15       3              0       2500.0
# 8479     U08480  2019-11-13   2020-06-24       4              0          0.0
# 8480     U08481  2020-07-09   2020-11-23       4           2015          0.0
# 8481     U08482  2020-11-29   2020-11-29       4              0          0.0
#
#       last_salary                    text_keyword job_code_seq1 job_code_seq2  \
# 0          1500.0                            디자이너   재료·화학·섬유·의복           NaN
# 1             0.0                            디자이너   재료·화학·섬유·의복           NaN
# 2             0.0                   남성복디자이너;TD캐주얼   재료·화학·섬유·의복           NaN
# 3             0.0                       상품기획;영업기획   재료·화학·섬유·의복           NaN
# 4             0.0                인사;총무;경영;MD;상품기획   재료·화학·섬유·의복           NaN
# ...           ...                             ...           ...           ...
# 8477       2700.0                            상품기획   재료·화학·섬유·의복           NaN
# 8478       2300.0                            디자이너   재료·화학·섬유·의복           NaN
# 8479          0.0  VMD;텍스타일디자인;섬유디자인;니트디자인;여성복디자인           디자인           NaN
# 8480       2700.0                 상품기획;머천다이저;기획MD   재료·화학·섬유·의복           NaN
# 8481          0.0     상품기획;영업MD;머천다이저;기획MD;마케팅;PR   재료·화학·섬유·의복           NaN
#
#       ... hischool_gender  hischool_location_seq univ_type_seq1  \
# 0     ...            여자학교                      4              5
# 1     ...              기타                      0              5
# 2     ...            남여공학                      6              5
# 3     ...            남여공학                      5              5
# 4     ...            여자학교                      5              0
# ...   ...             ...                    ...            ...
# 8477  ...            남여공학                      3              5
# 8478  ...            남여공학                      3              3
# 8479  ...              기타                      0              5
# 8480  ...            여자학교                      5              5
# 8481  ...            여자학교                      8              0
#
#      univ_type_seq2  univ_transfer univ_location       univ_major  \
# 0                 5              0            17              NaN
# 1                 5              0             3              NaN
# 2                 5              0            17              NaN
# 3                 5              0             5              NaN
# 4                 0              0             0              NaN
# ...             ...            ...           ...              ...
# 8477              5              0             5              NaN
# 8478              6              0             3              가정과
# 8479              5              0            10  미술대학섬유패션코디네이션학과
# 8480              5              0             5              NaN
# 8481              0              0             0              NaN
#
#      univ_sub_major  univ_major_type  univ_score
# 0               NaN                9        20.0
# 1               NaN                8        90.0
# 2               NaN                4        90.0
# 3               NaN                3        70.0
# 4               NaN               10        50.0
# ...             ...              ...         ...
# 8477            NaN               19         0.0
# 8478            NaN                9         0.0
# 8479            NaN                9        80.0
# 8480            NaN                9        60.0
# 8481            NaN                9        80.0
#
# [8482 rows x 27 columns]

# %%
merged_resume = pd.merge(merged_resume, resume_language, on='resume_seq', how='left')
merged_resume
# Out:
#      resume_seq    reg_date updated_date  degree  graduate_date  hope_salary  \
# 0        U00001  2019-12-27   2020-02-01       4           2009       1500.0
# 1        U00002  2020-04-24   2020-04-29       4           2005          0.0
# 2        U00003  2018-02-14   2020-07-08       4           2004          0.0
# 3        U00004  2017-10-26   2020-04-27       4           2011          0.0
# 4        U00005  2020-03-18   2020-04-08       4           2011          0.0
# ...         ...         ...          ...     ...            ...          ...
# 8477     U08478  2020-02-05   2020-03-31       4           2003          0.0
# 8478     U08479  2016-02-17   2020-07-15       3              0       2500.0
# 8479     U08480  2019-11-13   2020-06-24       4              0          0.0
# 8480     U08481  2020-07-09   2020-11-23       4           2015          0.0
# 8481     U08482  2020-11-29   2020-11-29       4              0          0.0
#
#       last_salary                    text_keyword job_code_seq1 job_code_seq2  \
# 0          1500.0                            디자이너   재료·화학·섬유·의복           NaN
# 1             0.0                            디자이너   재료·화학·섬유·의복           NaN
# 2             0.0                   남성복디자이너;TD캐주얼   재료·화학·섬유·의복           NaN
# 3             0.0                       상품기획;영업기획   재료·화학·섬유·의복           NaN
# 4             0.0                인사;총무;경영;MD;상품기획   재료·화학·섬유·의복           NaN
# ...           ...                             ...           ...           ...
# 8477       2700.0                            상품기획   재료·화학·섬유·의복           NaN
# 8478       2300.0                            디자이너   재료·화학·섬유·의복           NaN
# 8479          0.0  VMD;텍스타일디자인;섬유디자인;니트디자인;여성복디자인           디자인           NaN
# 8480       2700.0                 상품기획;머천다이저;기획MD   재료·화학·섬유·의복           NaN
# 8481          0.0     상품기획;영업MD;머천다이저;기획MD;마케팅;PR   재료·화학·섬유·의복           NaN
#
#       ... hischool_location_seq  univ_type_seq1 univ_type_seq2 univ_transfer  \
# 0     ...                     4               5              5             0
# 1     ...                     0               5              5             0
# 2     ...                     6               5              5             0
# 3     ...                     5               5              5             0
# 4     ...                     5               0              0             0
# ...   ...                   ...             ...            ...           ...
# 8477  ...                     3               5              5             0
# 8478  ...                     3               3              6             0
# 8479  ...                     0               5              5             0
# 8480  ...                     5               5              5             0
# 8481  ...                     8               0              0             0
#
#       univ_location       univ_major univ_sub_major univ_major_type  \
# 0                17              NaN            NaN               9
# 1                 3              NaN            NaN               8
# 2                17              NaN            NaN               4
# 3                 5              NaN            NaN               3
# 4                 0              NaN            NaN              10
# ...             ...              ...            ...             ...
# 8477              5              NaN            NaN              19
# 8478              3              가정과            NaN               9
# 8479             10  미술대학섬유패션코디네이션학과            NaN               9
# 8480              5              NaN            NaN               9
# 8481              0              NaN            NaN               9
#
#       univ_score  lang_exam_score
# 0           20.0              NaN
# 1           90.0              NaN
# 2           90.0              NaN
# 3           70.0      2;11;661.62
# 4           50.0       2;4;873.74
# ...          ...              ...
# 8477         0.0              NaN
# 8478         0.0              NaN
# 8479        80.0              NaN
# 8480        60.0              NaN
# 8481        80.0       2;11;600.0
#
# [8482 rows x 28 columns]

# %%
resume_train = pd.merge(resume_train, merged_resume, on='resume_seq', how='left')
resume_train
# Out:
#      resume_seq                                    recruitment_seq  \
# 0        U00001                        R05210;R05288;R04536;R06065
# 1        U00002  R01103;R01730;R06019;R01960;R02946;R02346;R045...
# 2        U00003                               R03301;R04918;R01460
# 3        U00004  R05367;R04166;R02355;R02003;R02899;R00312;R000...
# 4        U00005                               R00832;R03914;R00374
# ...         ...                                                ...
# 8477     U08478                                      R02170;R03939
# 8478     U08479          R02988;R03837;R01470;R04036;R04196;R02787
# 8479     U08480                                      R03152;R00803
# 8480     U08481                               R06253;R00225;R05500
# 8481     U08482                               R03633;R03743;R06282
#
#         reg_date updated_date  degree  graduate_date  hope_salary  \
# 0     2019-12-27   2020-02-01       4           2009       1500.0
# 1     2020-04-24   2020-04-29       4           2005          0.0
# 2     2018-02-14   2020-07-08       4           2004          0.0
# 3     2017-10-26   2020-04-27       4           2011          0.0
# 4     2020-03-18   2020-04-08       4           2011          0.0
# ...          ...          ...     ...            ...          ...
# 8477  2020-02-05   2020-03-31       4           2003          0.0
# 8478  2016-02-17   2020-07-15       3              0       2500.0
# 8479  2019-11-13   2020-06-24       4              0          0.0
# 8480  2020-07-09   2020-11-23       4           2015          0.0
# 8481  2020-11-29   2020-11-29       4              0          0.0
#
#       last_salary                    text_keyword job_code_seq1  ...  \
# 0          1500.0                            디자이너   재료·화학·섬유·의복  ...
# 1             0.0                            디자이너   재료·화학·섬유·의복  ...
# 2             0.0                   남성복디자이너;TD캐주얼   재료·화학·섬유·의복  ...
# 3             0.0                       상품기획;영업기획   재료·화학·섬유·의복  ...
# 4             0.0                인사;총무;경영;MD;상품기획   재료·화학·섬유·의복  ...
# ...           ...                             ...           ...  ...
# 8477       2700.0                            상품기획   재료·화학·섬유·의복  ...
# 8478       2300.0                            디자이너   재료·화학·섬유·의복  ...
# 8479          0.0  VMD;텍스타일디자인;섬유디자인;니트디자인;여성복디자인           디자인  ...
# 8480       2700.0                 상품기획;머천다이저;기획MD   재료·화학·섬유·의복  ...
# 8481          0.0     상품기획;영업MD;머천다이저;기획MD;마케팅;PR   재료·화학·섬유·의복  ...
#
#      hischool_location_seq univ_type_seq1  univ_type_seq2 univ_transfer  \
# 0                        4              5               5             0
# 1                        0              5               5             0
# 2                        6              5               5             0
# 3                        5              5               5             0
# 4                        5              0               0             0
# ...                    ...            ...             ...           ...
# 8477                     3              5               5             0
# 8478                     3              3               6             0
# 8479                     0              5               5             0
# 8480                     5              5               5             0
# 8481                     8              0               0             0
#
#      univ_location       univ_major univ_sub_major univ_major_type univ_score  \
# 0               17              NaN            NaN               9       20.0
# 1                3              NaN            NaN               8       90.0
# 2               17              NaN            NaN               4       90.0
# 3                5              NaN            NaN               3       70.0
# 4                0              NaN            NaN              10       50.0
# ...            ...              ...            ...             ...        ...
# 8477             5              NaN            NaN              19        0.0
# 8478             3              가정과            NaN               9        0.0
# 8479            10  미술대학섬유패션코디네이션학과            NaN               9       80.0
# 8480             5              NaN            NaN               9       60.0
# 8481             0              NaN            NaN               9       80.0
#
#       lang_exam_score
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3         2;11;661.62
# 4          2;4;873.74
# ...               ...
# 8477              NaN
# 8478              NaN
# 8479              NaN
# 8480              NaN
# 8481       2;11;600.0
#
# [8482 rows x 29 columns]

# %% [markdown]
# idx 대신 resume_seq를 직접 사용

# %%
'''merged_resume.set_index('resume_seq', inplace=True)
merged_resume'''
# Out:
# "merged_resume.set_index('resume_seq', inplace=True)\nmerged_resume"

# %% [markdown]
# ## company (recruitment_seq 기준)

# %%
recruitment_train = apply_train.groupby('recruitment_seq')['resume_seq'].apply(';'.join).reset_index()
recruitment_train
# Out:
#      recruitment_seq                                         resume_seq
# 0             R00001  U01670;U03957;U04097;U04364;U04491;U04614;U055...
# 1             R00002          U00886;U01013;U01875;U02642;U03778;U04822
# 2             R00003   U03528;U05517;U05808;U06416;U07010;U08000;U08089
# 3             R00004  U00004;U00164;U00296;U00490;U01421;U01519;U016...
# 4             R00005                 U00695;U01407;U02905;U08049;U08344
# ...              ...                                                ...
# 6690          R06691          U01236;U03261;U04141;U04861;U05018;U05625
# 6691          R06692  U00036;U00243;U01206;U03975;U04666;U05870;U065...
# 6692          R06693                        U02092;U03866;U08018;U08281
# 6693          R06694   U01074;U02793;U04648;U05548;U05762;U06373;U06672
# 6694          R06695  U00749;U01486;U02345;U03440;U03473;U03959;U048...
#
# [6695 rows x 2 columns]

# %%
company = pd.read_csv('./company.csv')
company = company.sort_values(by='recruitment_seq')
company
# Out:
#      recruitment_seq  company_type_seq  supply_kind  employee
# 1103          R00001                 5          201       631
# 2343          R00002                 2          201       160
# 1986          R00004                 2          402       500
# 352           R00009                 2          402        41
# 1087          R00011                 2          100       200
# ...              ...               ...          ...       ...
# 1439          R06670                 5          402       300
# 1808          R06676                 2          402        11
# 811           R06677                 9          402        20
# 1449          R06688                 2          402        90
# 1753          R06692                 4          402       150
#
# [2377 rows x 4 columns]

# %%
recruitment = pd.read_csv('./recruitment.csv')
recruitment = recruitment.sort_values(by='recruitment_seq')
recruitment
# Out:
#      recruitment_seq  address_seq1  address_seq2  address_seq3  career_end  \
# 4573          R00001           5.0           NaN           NaN           0
# 5915          R00002           3.0           NaN           NaN           0
# 6454          R00003           3.0           NaN           NaN           0
# 5905          R00004           3.0           NaN           NaN           0
# 4197          R00005           3.0           NaN           NaN           0
# ...              ...           ...           ...           ...         ...
# 5983          R06691           3.0           NaN           NaN           0
# 2367          R06692           3.0           NaN           NaN           0
# 6235          R06693           5.0           NaN           NaN           0
# 3298          R06694           3.0           NaN           NaN           0
# 2075          R06695           3.0           NaN           NaN           0
#
#       career_start                   check_box_keyword  education  major_task  \
# 4573             0  2101;2108;2201;2204;2205;2707;2810          2           2
# 5915             0                      2507;2703;2707          3           2
# 6454             0                 2101;2108;2201;2707          3           2
# 5905             0                           2507;2707          3           2
# 4197             0                           2507;2707          3           2
# ...            ...                                 ...        ...         ...
# 5983             0                      2501;2507;2707          3           2
# 2367             0                           2201;2507          3           2
# 6235             0                           2102;2707          4           2
# 3298             0  2101;2108;2109;2110;2201;2203;2707          4           2
# 2075             0                           2507;2707          3           2
#
#       qualifications text_keyword
# 4573               1          NaN
# 5915               1          NaN
# 6454               2          NaN
# 5905               1          NaN
# 4197               1          NaN
# ...              ...          ...
# 5983               1          NaN
# 2367               2          NaN
# 6235               1          NaN
# 3298               1          NaN
# 2075               1          NaN
#
# [6695 rows x 11 columns]

# %% [markdown]
# company 같은 경우 자료가 2377개 있으니 recruitment에 합쳐지는게 좋음

# %%
merged_recruitment = pd.merge(recruitment, company, on='recruitment_seq', how='left')
merged_recruitment
# Out:
#      recruitment_seq  address_seq1  address_seq2  address_seq3  career_end  \
# 0             R00001           5.0           NaN           NaN           0
# 1             R00002           3.0           NaN           NaN           0
# 2             R00003           3.0           NaN           NaN           0
# 3             R00004           3.0           NaN           NaN           0
# 4             R00005           3.0           NaN           NaN           0
# ...              ...           ...           ...           ...         ...
# 6690          R06691           3.0           NaN           NaN           0
# 6691          R06692           3.0           NaN           NaN           0
# 6692          R06693           5.0           NaN           NaN           0
# 6693          R06694           3.0           NaN           NaN           0
# 6694          R06695           3.0           NaN           NaN           0
#
#       career_start                   check_box_keyword  education  major_task  \
# 0                0  2101;2108;2201;2204;2205;2707;2810          2           2
# 1                0                      2507;2703;2707          3           2
# 2                0                 2101;2108;2201;2707          3           2
# 3                0                           2507;2707          3           2
# 4                0                           2507;2707          3           2
# ...            ...                                 ...        ...         ...
# 6690             0                      2501;2507;2707          3           2
# 6691             0                           2201;2507          3           2
# 6692             0                           2102;2707          4           2
# 6693             0  2101;2108;2109;2110;2201;2203;2707          4           2
# 6694             0                           2507;2707          3           2
#
#       qualifications text_keyword  company_type_seq  supply_kind  employee
# 0                  1          NaN               5.0        201.0     631.0
# 1                  1          NaN               2.0        201.0     160.0
# 2                  2          NaN               NaN          NaN       NaN
# 3                  1          NaN               2.0        402.0     500.0
# 4                  1          NaN               NaN          NaN       NaN
# ...              ...          ...               ...          ...       ...
# 6690               1          NaN               NaN          NaN       NaN
# 6691               2          NaN               4.0        402.0     150.0
# 6692               1          NaN               NaN          NaN       NaN
# 6693               1          NaN               NaN          NaN       NaN
# 6694               1          NaN               NaN          NaN       NaN
#
# [6695 rows x 14 columns]

# %%
merged_recruitment.set_index('recruitment_seq', inplace=True)
merged_recruitment
# Out:
#                  address_seq1  address_seq2  address_seq3  career_end  \
# recruitment_seq
# R00001                    5.0           NaN           NaN           0
# R00002                    3.0           NaN           NaN           0
# R00003                    3.0           NaN           NaN           0
# R00004                    3.0           NaN           NaN           0
# R00005                    3.0           NaN           NaN           0
# ...                       ...           ...           ...         ...
# R06691                    3.0           NaN           NaN           0
# R06692                    3.0           NaN           NaN           0
# R06693                    5.0           NaN           NaN           0
# R06694                    3.0           NaN           NaN           0
# R06695                    3.0           NaN           NaN           0
#
#                  career_start                   check_box_keyword  education  \
# recruitment_seq
# R00001                      0  2101;2108;2201;2204;2205;2707;2810          2
# R00002                      0                      2507;2703;2707          3
# R00003                      0                 2101;2108;2201;2707          3
# R00004                      0                           2507;2707          3
# R00005                      0                           2507;2707          3
# ...                       ...                                 ...        ...
# R06691                      0                      2501;2507;2707          3
# R06692                      0                           2201;2507          3
# R06693                      0                           2102;2707          4
# R06694                      0  2101;2108;2109;2110;2201;2203;2707          4
# R06695                      0                           2507;2707          3
#
#                  major_task  qualifications text_keyword  company_type_seq  \
# recruitment_seq
# R00001                    2               1          NaN               5.0
# R00002                    2               1          NaN               2.0
# R00003                    2               2          NaN               NaN
# R00004                    2               1          NaN               2.0
# R00005                    2               1          NaN               NaN
# ...                     ...             ...          ...               ...
# R06691                    2               1          NaN               NaN
# R06692                    2               2          NaN               4.0
# R06693                    2               1          NaN               NaN
# R06694                    2               1          NaN               NaN
# R06695                    2               1          NaN               NaN
#
#                  supply_kind  employee
# recruitment_seq
# R00001                 201.0     631.0
# R00002                 201.0     160.0
# R00003                   NaN       NaN
# R00004                 402.0     500.0
# R00005                   NaN       NaN
# ...                      ...       ...
# R06691                   NaN       NaN
# R06692                 402.0     150.0
# R06693                   NaN       NaN
# R06694                   NaN       NaN
# R06695                   NaN       NaN
#
# [6695 rows x 13 columns]

# %%
merged_recruitment = merged_recruitment.fillna(0) # NaN 값 0으로 대체
merged_recruitment
# Out:
#                  address_seq1  address_seq2  address_seq3  career_end  \
# recruitment_seq
# R00001                    5.0           0.0           0.0           0
# R00002                    3.0           0.0           0.0           0
# R00003                    3.0           0.0           0.0           0
# R00004                    3.0           0.0           0.0           0
# R00005                    3.0           0.0           0.0           0
# ...                       ...           ...           ...         ...
# R06691                    3.0           0.0           0.0           0
# R06692                    3.0           0.0           0.0           0
# R06693                    5.0           0.0           0.0           0
# R06694                    3.0           0.0           0.0           0
# R06695                    3.0           0.0           0.0           0
#
#                  career_start                   check_box_keyword  education  \
# recruitment_seq
# R00001                      0  2101;2108;2201;2204;2205;2707;2810          2
# R00002                      0                      2507;2703;2707          3
# R00003                      0                 2101;2108;2201;2707          3
# R00004                      0                           2507;2707          3
# R00005                      0                           2507;2707          3
# ...                       ...                                 ...        ...
# R06691                      0                      2501;2507;2707          3
# R06692                      0                           2201;2507          3
# R06693                      0                           2102;2707          4
# R06694                      0  2101;2108;2109;2110;2201;2203;2707          4
# R06695                      0                           2507;2707          3
#
#                  major_task  qualifications text_keyword  company_type_seq  \
# recruitment_seq
# R00001                    2               1            0               5.0
# R00002                    2               1            0               2.0
# R00003                    2               2            0               0.0
# R00004                    2               1            0               2.0
# R00005                    2               1            0               0.0
# ...                     ...             ...          ...               ...
# R06691                    2               1            0               0.0
# R06692                    2               2            0               4.0
# R06693                    2               1            0               0.0
# R06694                    2               1            0               0.0
# R06695                    2               1            0               0.0
#
#                  supply_kind  employee
# recruitment_seq
# R00001                 201.0     631.0
# R00002                 201.0     160.0
# R00003                   0.0       0.0
# R00004                 402.0     500.0
# R00005                   0.0       0.0
# ...                      ...       ...
# R06691                   0.0       0.0
# R06692                 402.0     150.0
# R06693                   0.0       0.0
# R06694                   0.0       0.0
# R06695                   0.0       0.0
#
# [6695 rows x 13 columns]

# %%
recruitment_train = pd.merge(recruitment_train, merged_recruitment, on='recruitment_seq', how='left')
recruitment_train
# Out:
#      recruitment_seq                                         resume_seq  \
# 0             R00001  U01670;U03957;U04097;U04364;U04491;U04614;U055...
# 1             R00002          U00886;U01013;U01875;U02642;U03778;U04822
# 2             R00003   U03528;U05517;U05808;U06416;U07010;U08000;U08089
# 3             R00004  U00004;U00164;U00296;U00490;U01421;U01519;U016...
# 4             R00005                 U00695;U01407;U02905;U08049;U08344
# ...              ...                                                ...
# 6690          R06691          U01236;U03261;U04141;U04861;U05018;U05625
# 6691          R06692  U00036;U00243;U01206;U03975;U04666;U05870;U065...
# 6692          R06693                        U02092;U03866;U08018;U08281
# 6693          R06694   U01074;U02793;U04648;U05548;U05762;U06373;U06672
# 6694          R06695  U00749;U01486;U02345;U03440;U03473;U03959;U048...
#
#       address_seq1  address_seq2  address_seq3  career_end  career_start  \
# 0              5.0           0.0           0.0           0             0
# 1              3.0           0.0           0.0           0             0
# 2              3.0           0.0           0.0           0             0
# 3              3.0           0.0           0.0           0             0
# 4              3.0           0.0           0.0           0             0
# ...            ...           ...           ...         ...           ...
# 6690           3.0           0.0           0.0           0             0
# 6691           3.0           0.0           0.0           0             0
# 6692           5.0           0.0           0.0           0             0
# 6693           3.0           0.0           0.0           0             0
# 6694           3.0           0.0           0.0           0             0
#
#                        check_box_keyword  education  major_task  \
# 0     2101;2108;2201;2204;2205;2707;2810          2           2
# 1                         2507;2703;2707          3           2
# 2                    2101;2108;2201;2707          3           2
# 3                              2507;2707          3           2
# 4                              2507;2707          3           2
# ...                                  ...        ...         ...
# 6690                      2501;2507;2707          3           2
# 6691                           2201;2507          3           2
# 6692                           2102;2707          4           2
# 6693  2101;2108;2109;2110;2201;2203;2707          4           2
# 6694                           2507;2707          3           2
#
#       qualifications text_keyword  company_type_seq  supply_kind  employee
# 0                  1            0               5.0        201.0     631.0
# 1                  1            0               2.0        201.0     160.0
# 2                  2            0               0.0          0.0       0.0
# 3                  1            0               2.0        402.0     500.0
# 4                  1            0               0.0          0.0       0.0
# ...              ...          ...               ...          ...       ...
# 6690               1            0               0.0          0.0       0.0
# 6691               2            0               4.0        402.0     150.0
# 6692               1            0               0.0          0.0       0.0
# 6693               1            0               0.0          0.0       0.0
# 6694               1            0               0.0          0.0       0.0
#
# [6695 rows x 15 columns]

# %% [markdown]
# # train 2개 유형

# %%
resume_train.shape
# Out:
# (8482, 29)

# %%
recruitment_train.shape
# Out:
# (6695, 15)

# %% [markdown]
# # 생각 정리

# %% [markdown]
# 여러개인 경우 ;으로 묶어두고
# 언어 같은 경우 & 으로 나눔

# %% [markdown]
# # 함수 정의

# %% [markdown]
# # 사용할 것 정리

# %%
resume_train_x = resume_train[['resume_seq', 'text_keyword', 'job_code_seq1', 'univ_major_type']]
resume_train_x
# Out:
#      resume_seq                    text_keyword job_code_seq1  univ_major_type
# 0        U00001                            디자이너   재료·화학·섬유·의복                9
# 1        U00002                            디자이너   재료·화학·섬유·의복                8
# 2        U00003                   남성복디자이너;TD캐주얼   재료·화학·섬유·의복                4
# 3        U00004                       상품기획;영업기획   재료·화학·섬유·의복                3
# 4        U00005                인사;총무;경영;MD;상품기획   재료·화학·섬유·의복               10
# ...         ...                             ...           ...              ...
# 8477     U08478                            상품기획   재료·화학·섬유·의복               19
# 8478     U08479                            디자이너   재료·화학·섬유·의복                9
# 8479     U08480  VMD;텍스타일디자인;섬유디자인;니트디자인;여성복디자인           디자인                9
# 8480     U08481                 상품기획;머천다이저;기획MD   재료·화학·섬유·의복                9
# 8481     U08482     상품기획;영업MD;머천다이저;기획MD;마케팅;PR   재료·화학·섬유·의복                9
#
# [8482 rows x 4 columns]

# %%
resume_train_x.isnull().sum()
# Out:
# resume_seq           0
# text_keyword       195
# job_code_seq1        0
# univ_major_type      0
# dtype: int64

# %%
#학습, 검증 분리
train, test = [], []
apply_train_groupby = apply_train.groupby('resume_seq')['recruitment_seq'].apply(list)
for uid, iids in zip(apply_train_groupby.index.tolist(), apply_train_groupby.values.tolist()):
    for iid in iids[:-1]:
        train.append([uid,iid])
    test.append([uid, iids[-1]])

# %% [markdown]
# 여기서 test는 answer_df 으로 우리가 안에서 맞춰야하는 것이다.

# %%
train = pd.DataFrame(train, columns=['resume_seq', 'recruitment_seq'])
test = pd.DataFrame(test, columns=['resume_seq', 'recruitment_seq'])
pred = apply_train.copy()

# %%
train = train.groupby(['resume_seq', 'recruitment_seq']).size().unstack(fill_value=0)
pred = pred.groupby(['resume_seq', 'recruitment_seq']).size().unstack(fill_value=0)
train
# Out:
# recruitment_seq  R00001  R00002  R00003  R00004  R00005  R00006  R00007  \
# resume_seq
# U00001                0       0       0       0       0       0       0
# U00002                0       0       0       0       0       0       0
# U00003                0       0       0       0       0       0       0
# U00004                0       0       0       1       0       0       0
# U00005                0       0       0       0       0       0       0
# ...                 ...     ...     ...     ...     ...     ...     ...
# U08478                0       0       0       0       0       0       0
# U08479                0       0       0       0       0       0       0
# U08480                0       0       0       0       0       0       0
# U08481                0       0       0       0       0       0       0
# U08482                0       0       0       0       0       0       0
#
# recruitment_seq  R00008  R00009  R00010  ...  R06686  R06687  R06688  R06689  \
# resume_seq                               ...
# U00001                0       0       0  ...       0       0       0       0
# U00002                0       0       0  ...       0       0       0       0
# U00003                0       0       0  ...       0       0       0       0
# U00004                0       0       0  ...       0       0       0       0
# U00005                0       0       0  ...       0       0       0       0
# ...                 ...     ...     ...  ...     ...     ...     ...     ...
# U08478                0       0       0  ...       0       0       0       0
# U08479                0       0       0  ...       0       0       0       0
# U08480                0       0       0  ...       0       0       0       0
# U08481                0       0       0  ...       0       0       0       0
# U08482                0       0       0  ...       0       0       0       0
#
# recruitment_seq  R06690  R06691  R06692  R06693  R06694  R06695
# resume_seq
# U00001                0       0       0       0       0       0
# U00002                0       0       0       0       0       0
# U00003                0       0       0       0       0       0
# U00004                0       0       0       0       0       0
# U00005                0       0       0       0       0       0
# ...                 ...     ...     ...     ...     ...     ...
# U08478                0       0       0       0       0       0
# U08479                0       0       0       0       0       0
# U08480                0       0       0       0       0       0
# U08481                0       0       0       0       0       0
# U08482                0       0       0       0       0       0
#
# [8482 rows x 6690 columns]

# %%
'''train = pd.merge(train, resume_train_x, on='resume_seq', how='left')
train'''
# Out:
# "train = pd.merge(train, resume_train_x, on='resume_seq', how='left')\ntrain"

# %%
train2 = resume_train_x[['resume_seq', 'text_keyword']]
pred2 = resume_train_x[['resume_seq', 'text_keyword']]

# %%
train2 = train2.set_index(['resume_seq'])['text_keyword'].str.split(';', expand=True).stack().reset_index().drop('level_1', axis=1)
train2.columns = ['resume_seq', 'text_keyword']
pred2 = pred2.set_index(['resume_seq'])['text_keyword'].str.split(';', expand=True).stack().reset_index().drop('level_1', axis=1)
pred2.columns = ['resume_seq', 'text_keyword']
train2
# Out:
#       resume_seq text_keyword
# 0         U00001         디자이너
# 1         U00002         디자이너
# 2         U00003      남성복디자이너
# 3         U00003        TD캐주얼
# 4         U00004         상품기획
# ...          ...          ...
# 28055     U08482         영업MD
# 28056     U08482        머천다이저
# 28057     U08482         기획MD
# 28058     U08482          마케팅
# 28059     U08482           PR
#
# [28060 rows x 2 columns]

# %%
train2 = train2.groupby(['resume_seq', 'text_keyword']).size().unstack(fill_value=0)
pred2 = pred2.groupby(['resume_seq', 'text_keyword']).size().unstack(fill_value=0)

# %%
train3 = resume_train_x[['resume_seq', 'job_code_seq1']]
pred3 = resume_train_x[['resume_seq', 'job_code_seq1']]

# %%
train3 = train3.groupby(['resume_seq', 'job_code_seq1']).size().unstack(fill_value=0)
pred3 = pred3.groupby(['resume_seq', 'job_code_seq1']).size().unstack(fill_value=0)

# %%
train4 = resume_train_x[['resume_seq', 'univ_major_type']]
pred4 = resume_train_x[['resume_seq', 'univ_major_type']]

# %%
train4 = train4.groupby(['resume_seq', 'univ_major_type']).size().unstack(fill_value=0)
pred4 = pred4.groupby(['resume_seq', 'univ_major_type']).size().unstack(fill_value=0)

# %%
train = pd.merge(train, train2, on='resume_seq', how='left')
train = pd.merge(train, train3, on='resume_seq', how='left')
train = pd.merge(train, train4, on='resume_seq', how='left')

pred = pd.merge(train, pred2, on='resume_seq', how='left')
pred = pd.merge(train, pred3, on='resume_seq', how='left')
pred = pd.merge(train, pred4, on='resume_seq', how='left')

# %% [markdown]
# # train null 지우기

# %%
train.fillna(0, inplace=True)
pred.fillna(0, inplace=True)

# %% [markdown]
# # 그냥 cosine

# %%
train_user_similarity = cosine_similarity(train)
train_item_similarity = cosine_similarity(train.T)

pred_user_similarity = cosine_similarity(pred)
pred_item_similarity = cosine_similarity(pred.T)

# %%
train_user_predicted_scores = train_user_similarity.dot(train)
train_item_predicted_scores = train.dot(train_item_similarity)

pred_user_predicted_scores = pred_user_similarity.dot(pred)
pred_item_predicted_scores = pred.dot(pred_item_similarity)

# %%
alpha = 0.42
train_recommendations = []

# R0로 시작하는 항목만을 추출
target_columns = [col for col in train.columns if col.startswith('R0')]

for idx, user in tqdm(enumerate(train.index)):
    applied_jobs = set(train.loc[user][train.loc[user] == 1].index)

    # 해당 사용자의 추천 점수 (높은 점수부터 정렬)
    sorted_job_indices = (train_item_predicted_scores.loc[user].values * alpha + train_user_predicted_scores[idx]).argsort()[::-1]
    recommended_jobs = [job for job in train.columns[sorted_job_indices] if job not in applied_jobs and job in target_columns][:5]

    for job in recommended_jobs:
        train_recommendations.append([user, job])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-b8d4d93a690e> in <cell line: 4>()
#       2 train_recommendations = []
#       3 # R0로 시작하는 항목만을 추출
# ----> 4 target_columns = [col for col in train.columns if col.startswith('R0')]
#       5
#       6 for idx, user in tqdm(enumerate(train.index)):
#
# <ipython-input-67-b8d4d93a690e> in <listcomp>(.0)
#       2 train_recommendations = []
#       3 # R0로 시작하는 항목만을 추출
# ----> 4 target_columns = [col for col in train.columns if col.startswith('R0')]
#       5
#       6 for idx, user in tqdm(enumerate(train.index)):
#
# AttributeError: 'int' object has no attribute 'startswith'

# %%
val_prediction = pd.DataFrame(train_recommendations, columns=['resume_seq', 'recruitment_seq'])

# %%
recall5(test,val_prediction)
# Out:
# 0.0

# %%
alpha = 0.42
pred_recommendations = []

target_columns = [col for col in train.columns if col.startswith('R0')]

for idx, user in tqdm(enumerate(train.index)):
    applied_jobs = set(train.loc[user][train.loc[user] == 1].index)

    # 해당 사용자의 추천 점수 (높은 점수부터 정렬)
    sorted_job_indices = (train_item_predicted_scores.loc[user].values * alpha + train_user_predicted_scores[idx]).argsort()[::-1]
    recommended_jobs = [job for job in train.columns[sorted_job_indices] if job not in applied_jobs and job in target_columns][:5]

    for job in recommended_jobs:
        train_recommendations.append([user, job])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-edf2a7b7728a> in <cell line: 4>()
#       2 pred_recommendations = []
#       3
# ----> 4 target_columns = [col for col in train.columns if col.startswith('R0')]
#       5
#       6 for idx, user in tqdm(enumerate(train.index)):
#
# <ipython-input-66-edf2a7b7728a> in <listcomp>(.0)
#       2 pred_recommendations = []
#       3
# ----> 4 target_columns = [col for col in train.columns if col.startswith('R0')]
#       5
#       6 for idx, user in tqdm(enumerate(train.index)):
#
# AttributeError: 'int' object has no attribute 'startswith'

# %%
top_recommendations = pd.DataFrame(pred_recommendations, columns=['resume_seq', 'recruitment_seq'])
top_recommendations.to_csv('./baseline_add_item_0.98.csv', index=False)

# %% [markdown]
# # 범주형 데이터 형변환

# %% [markdown]
# # 수치형 스케일링

# %% [markdown]
# # 수치형, 범주형 합치기

# %% [markdown]
# # K-Fold

# %%
# 교차 검증
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# # Model

# %% [markdown]
# ## DecisionTree
